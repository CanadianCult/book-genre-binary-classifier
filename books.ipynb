# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow
from collections import defaultdict

# %%
df = pd.read_csv("/content/book_data.csv")
df.head()
# Out:
#                                         book_authors  \
# 0                                    Suzanne Collins
# 1                         J.K. Rowling|Mary GrandPré
# 2                                         Harper Lee
# 3  Jane Austen|Anna Quindlen|Mrs. Oliphant|George...
# 4                                    Stephenie Meyer
#
#                                            book_desc  \
# 0  Winning will make you famous. Losing means cer...
# 1  There is a door at the end of a silent corrido...
# 2  The unforgettable novel of a childhood in a sl...
# 3  «È cosa ormai risaputa che a uno scapolo in po...
# 4  About three things I was absolutely positive.F...
#
#                          book_edition book_format    book_isbn book_pages  \
# 0                                 NaN   Hardcover  9.78044E+12  374 pages
# 1                          US Edition   Paperback  9.78044E+12  870 pages
# 2                    50th Anniversary   Paperback  9.78006E+12  324 pages
# 3  Modern Library Classics, USA / CAN   Paperback  9.78068E+12  279 pages
# 4                                 NaN   Paperback  9.78032E+12  498 pages
#
#    book_rating  book_rating_count  book_review_count  \
# 0         4.33            5519135             160706
# 1         4.48            2041594              33264
# 2         4.27            3745197              79450
# 3         4.25            2453620              54322
# 4         3.58            4281268              97991
#
#                                   book_title  \
# 0                           The Hunger Games
# 1  Harry Potter and the Order of the Phoenix
# 2                      To Kill a Mockingbird
# 3                        Pride and Prejudice
# 4                                   Twilight
#
#                                               genres  \
# 0  Young Adult|Fiction|Science Fiction|Dystopia|F...
# 1                        Fantasy|Young Adult|Fiction
# 2  Classics|Fiction|Historical|Historical Fiction...
# 3                           Classics|Fiction|Romance
# 4  Young Adult|Fantasy|Romance|Paranormal|Vampire...
#
#                                            image_url
# 0  https://images.gr-assets.com/books/1447303603l...
# 1  https://images.gr-assets.com/books/1255614970l...
# 2  https://images.gr-assets.com/books/1361975680l...
# 3  https://images.gr-assets.com/books/1320399351l...
# 4  https://images.gr-assets.com/books/1361039443l...

# %%
df.dropna(subset=["genres", "book_desc"], inplace=True)

# %%
data = df.copy()

# %% [markdown]
# Calculating the frequency of each genre

# %%
def genre_count(x):
    try:
        return len(x.split('|'))
    except:
        return 0

data['genre_count'] = data['genres'].map(lambda x: genre_count(x))

# %% [markdown]
# make a genre columns into a list of all genres

# %%
def genre_listing(x):
    try:
        lst = [genre for genre in x.split("|")]
        return lst
    except:
        return []

data['genre_list'] = data['genres'].map(lambda x: genre_listing(x))

# %%
genre_dict = defaultdict(int)
for index, row in data.iterrows():
  book_genres = row["genre_list"]
  if type(book_genres) == list:
    for genre in book_genres:
      genre_dict[genre] += 1

# %%
len(genre_dict)
# Out:
# 864

# %%
genre_pd = pd.DataFrame.from_records(sorted(genre_dict.items(), key=lambda x:x[1], reverse=True),
                                     columns=['genre', 'count'])
genre_pd[:50].head()
# Out:
#          genre  count
# 0      Fiction  25736
# 1      Fantasy  23583
# 2      Romance  18636
# 3  Young Adult  11251
# 4   Historical  10789

# %%
def determine_fiction(x):
    lower_list = [genre.lower() for genre in x]
    if 'fiction' in lower_list:
        return 'fiction'
    elif 'nonfiction' in lower_list:
        return 'nonfiction'
    else:
        return 'others'
data['label'] = data['genre_list'].apply(determine_fiction)

# %%
data.label.value_counts()
# Out:
# fiction       25736
# others        16843
# nonfiction     7598
# Name: label, dtype: int64

# %%
data
# Out:
#                                             book_authors  \
# 0                                        Suzanne Collins
# 1                             J.K. Rowling|Mary GrandPré
# 2                                             Harper Lee
# 3      Jane Austen|Anna Quindlen|Mrs. Oliphant|George...
# 
# 0      [Young Adult, Fiction, Science Fiction, Dystop...     fiction
# 1                        [Fantasy, Young Adult, Fiction]     fiction
# 2      [Classics, Fiction, Historical, Historical Fic...     fiction
# 3                           [Classics, Fiction, Romance]     fiction
# 4      [Young Adult, Fantasy, Romance, Paranormal, Va...     fiction
# ...                                                  ...         ...
# 54295  [Nonfiction, Autobiography, Memoir, Biography,...  nonfiction
# 54296  [Sports, Baseball, Sports and Games, Sports, N...  nonfiction
# 54297             [Nonfiction, Sports and Games, Sports]  nonfiction
# 54299  [Nonfiction, Autobiography, Memoir, Biography,...  nonfiction
# 54300  [Criticism, Literary Criticism, Philosophy, Th...      others
#
# [50177 rows x 15 columns]

# %%
pip install langdetect
# Out:
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 17.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from langdetect) (1.16.0)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993224 sha256=d137d466522edb84b53e103421a6ab285f178ed282e749744a883fc4ae38a7d0
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built langdetect
# Installing collected packages: langdetect
# Successfully installed langdetect-1.0.9

# %%
df.columns
# Out:
# Index(['book_authors', 'book_desc', 'book_edition', 'book_format', 'book_isbn',
#        'book_pages', 'book_rating', 'book_rating_count', 'book_review_count',
#        'book_title', 'genres', 'image_url'],
#       dtype='object')

# %% [markdown]
# Preprocessing data

# %%
df.dropna(subset=["book_desc"], inplace=True)

# %%
df.dropna(subset=["genres"], inplace=True)

# %%
df
# Out:
#                                             book_authors  \
# 0                                        Suzanne Collins
# 1                             J.K. Rowling|Mary GrandPré
# 2                                             Harper Lee
# 3      Jane Austen|Anna Quindlen|Mrs. Oliphant|George...
# 4                                        Stephenie Meyer
# ...                                                  ...
# 27050                                      Nigel McCrery
# 27051                                     Winston Graham
# 27052  Jack Canfield|Mark Victor Hansen|Amy Newmark|A...
# 27053                                Thomas E. Sniegoski
# 27054                                      Sara Douglass
#
#                                                book_desc  \
# 0      Winning will make you famous. Losing means cer...
# 1      There is a door at the end of a silent corrido...
# 2      The unforgettable novel of a childhood in a sl...
# 3      «È cosa ormai risaputa che a uno scapolo in po...
# 4      About three things I was absolutely positive.F...
# ...                                                  ...
# 27050  Memories haunt Violet Chambers. Taking tea wit...
# 27051  Cornwall, 1818-1820The stories of the Poldark ...
# 27052  Teenage years are tough, but this book will he...
# 27053  DESTINED FOR HEAVEN OR HELL?Aaron's senior yea...
# 27054  Created by gods. Destroyed by revenge. Reborn ...
#
#                              book_edition book_format    book_isbn book_pages  \
# 0                                     NaN   Hardcover  9.78044E+12  374 pages
# 1                              US Edition   Paperback  9.78044E+12  870 pages
# 2                        50th Anniversary   Paperback  9.78006E+12  324 pages
# 3      Modern Library Classics, USA / CAN   Paperback  9.78068E+12  279 pages
# 4                                     NaN   Paperback  9.78032E+12  498 pages
# ...                                   ...         ...          ...        ...
# 27050                                 NaN   Paperback  9.78185E+12  389 pages
# 27051                                 NaN   Paperback  9.78033E+12  688 pages
# 27052                                 NaN   Paperback  9.78194E+12  384 pages
# 27053                                 NaN   Paperback  9.78144E+12  541 pages
# 27054                                 NaN   Paperback  9.78077E+12  637 pages
#
#        book_rating  book_rating_count  book_review_count  \
# 0             4.33            5519135             160706
# 1             4.48            2041594              33264
# 2             4.27            3745197              79450
# 3             4.25            2453620              54322
# 4             3.58            4281268              97991
# ...            ...                ...                ...
# 27050         3.70                651                 99
# 27051         4.30               2864                257
# 27052         4.13                121                 11
# 27053         4.09               7882                265
# 27054         3.88               3324                136
#
#                                               book_title  \
# 0                                       The Hunger Games
# 1              Harry Potter and the Order of the Phoenix
# 2                                  To Kill a Mockingbird
# 3                                    Pride and Prejudice
# 4                                               Twilight
# ...                                                  ...
# 27050                                       Core of Evil
# 27051                                      Bella Poldark
# 27052  Chicken Soup for the Soul: Just for Teenagers:...
# 27053                                Aerie and Reckoning
# 27054                                    Hades' Daughter
#
#                                                   genres  \
# 0      Young Adult|Fiction|Science Fiction|Dystopia|F...
# 1                            Fantasy|Young Adult|Fiction
# 2      Classics|Fiction|Historical|Historical Fiction...
# 3                               Classics|Fiction|Romance
# 4      Young Adult|Fantasy|Romance|Paranormal|Vampire...
# ...                                                  ...
# 27050  Mystery|Fiction|Mystery|Crime|European Literat...
# 27051  Historical|Historical Fiction|Fiction|Historic...
# 27052                           Nonfiction|Inspirational
# 27053  Paranormal|Angels|Young Adult|Fantasy|Fantasy|...
# 27054  Fantasy|Science Fiction Fantasy|Fantasy|Epic F...
#
#                                                image_url
# 0      https://images.gr-assets.com/books/1447303603l...
# 1      https://images.gr-assets.com/books/1255614970l...
# 2      https://images.gr-assets.com/books/1361975680l...
# 3      https://images.gr-assets.com/books/1320399351l...
# 4      https://images.gr-assets.com/books/1361039443l...
# ...                                                  ...
# 27050  https://images.gr-assets.com/books/1348064439l...
# 27051  https://images.gr-assets.com/books/1385276287l...
# 27052  https://images.gr-assets.com/books/1348577234l...
# 27053  https://images.gr-assets.com/books/1282266612l...
# 27054                             https://images.gr-asse
#
# [26620 rows x 12 columns]

# %%
from langdetect import detect

def is_english(text):
    try:
        lang = detect(text)
        if lang == 'en':
            return True
        else:
            return False
    except:
        return False

# %%
df['is_english'] = df['book_desc'].apply(lambda x: is_english(x))
df = df[df['is_english']]
df = df.drop(columns=['is_english'])

# %%
def detect_fiction(text):
  text = text.lower()
  words = text.split("|")
  if "fiction" in words:
    return "Fiction"
  if "nonfiction" in words:
    return "Non-Fiction"
  else:
    return "Other"

# %%
df["genres"] = df["genres"].apply(detect_fiction)

# %%
df.genres.value_counts()
# Out:
# Fiction        12174
# Other           7153
# Non-Fiction     3179
# Name: genres, dtype: int64

# %%
df[df["genres"] == "Other"]
# Out:
#                                             book_authors  \
# 27     Cassandra Clare|Franca Fritz|Heinrich Koop|Fra...
# 83                                         Richelle Mead
# 104                                      Cassandra Clare
# 116                                           Eric Carle
# 128                                    Becca Fitzpatrick
# ...                                                  ...
# 27031                                    Barnabas Miller
# 27036                                    Dana Marie Bell
# 27039                                       Vina Jackson
# 27053                                Thomas E. Sniegoski
# 27054                                      Sara Douglass
#
#                                                book_desc   book_edition  \
# 27     When fifteen-year-old Clary Fray heads out to ...            NaN
# 83     Only a true best friend can protect you from y...            NaN
# 104    In a time when Shadowhunters are barely winnin...  First Edition
# 116    THE all-time classic picture book, from genera...            NaN
# 128    A SACRED OATHA FALLEN ANGELA FORBIDDEN LOVERom...  First Edition
# ...                                                  ...            ...
# 27031  ARE YOU READY TO ROCK?Dear Sammy,The truth is ...            NaN
# 27036  The better to make you mine, my dear…When it c...            NaN
# 27039  \r\r\r\nIn the manner of Fifty Shades of Grey,...            NaN
# 27053  DESTINED FOR HEAVEN OR HELL?Aaron's senior yea...            NaN
# 27054  Created by gods. Destroyed by revenge. Reborn ...            NaN
#
#       book_format    book_isbn book_pages  book_rating  book_rating_count  \
#  'are still my heart; yes, they are a refrain',
#  'am00:00, only by expressing emotion, having expectations, do we get this surfacing',
#  'you don’t know how i really i feel.',
#  'a calling voice, never receiving a response, is drowned out in an instant.',
#  'i dash down the slope, just like a midnight ballerina;',
#  'i just wanna be with you, don’t be scared',
#  'until even desires and regrets are simply covered.',
#  'far from having enough, at am04:00 they dance with your shadowy impression.',
#  'i don’t want you anymore, i’m so good at getting hurt',
#  'the way to a dazzling heaven,',
#  'i came here, a bit of a distance away,',
#  'the sky is so moody, but it’s not all that uncommon; i’m doing just fine!',
#  'to me, you’re…?',
#  'so let’s decorate the sky with bouquets of that flower… whose name we’ve yet to know!',
#  'everyone wishes they could go to a gentler world.let us melt into one.',
#  'that i feel i want to see you again.',
#  'i overcame a sorrowful night',
#  'just speak, before my breath stops',
#  'tail lamps grow distant in a sad little way,',
#  'when you’re looking for something special,',
#  'this could take so long to find the way',
#  'the second i recognize the scent of rain, it travels farther away –',
#  'i try to break an unbreaking night –',
#  'i can find the way of love',
#  'there’s something beating in my heart, much more certain than my heartbeat!',
#  'to the unseen west of eden',
#  'all those people cry in vain n',
#  'stretched shadows and ginkgo trees… i wanted to continue watching this season.',
#  'torn asunder, i learn of pain.',
#  'spins the tale of a vague summer’s dream.',
#  'just stay by my side, forever.',
#  'as my wish is granted, i learn of pain.',
#  'on the inviting breeze of 02:00 am',
#  'dry winds rushing through street corners of dancing dry leaves…',
#  'i just wanna be with you, don’t leave me!',
#  'i’ll hum, beam with joy, and watch the streaks of stardust',
#  'i’ll entrust them to song, saying my goodbye: a song about love that no one even knows!',
#  'i can’t control sopping-wet nights',
#  'by the time it vanishes, i’ll be missing it dearly!',
#  'to a dazzling heaven,',
#  'it’s a feeling i understand less the more i think of you…',
#  'i’d already realized, but pretended i hadn’t noticed;',
#  'here’s the signlet’s get out',
#  'i’m writing a letter for me',
#  'and you’re there too, looking so bright – so much more beautiful than you were the day before!',
#  'only love need remain.sorrow alone falls heavily, piling up',
#  'all the unsightly masses.',
#  'it’s a cycle of sleepless nights and i can’t even open an umbrella',
#  'lie, lie, it’s a lie, not a lie. it’s just too much,',
#  'with hate and love, all mushed together',
#  'an unresting nightingale, under a spell,',
#  'but it seems to be o.k.',
#  'unable to say that i want to be by your side, unable to sleep,',
#  'will even the scars of that far-off spring day, when we formed our bonds,',
#  'rhythm and soul, we are',
#  'take my muddy hand.',
#  'my road home is just a bit more lovely than usual.',
#  'couldn’t manage to say goodbye.',
#  'don’t rip up our tears and dreams',
#  'don’t need luggage either3min with you, around the world',
#  'am01:00.',
#  'i feel you so far away, close and nearlet’s get out',
#  'giving a kiss to the wind, i can keep on walking; i’m doing just fine!',
#  'i’ll entrust them to song, saying my goodbye: a song about rain that no one even knows!',
#  'kick me around with the toe of your boot, if you please.',
#  'scattered clouds and a post-rain sky… roadside trees;',
#  'warmly, sweetly enveloped me',
#  'the false courage i’ve kept wrapped around my heart will surely become a newfound strength!',
#  'but it’s your love can be the real life line',
#  'even that rainbow is moody – a wonderful scene; i’m doing just fine!',
#  'and there’s something beating in my heart, much more certain than my heartbeat!',
#  'what’s real, what’s fake, truth, lies',
#  'you feel the world is calling?',
#  'all my friends have gone away',
#  'i’m dreamily having an unending dream…',
#  'for this one unable to return home, morning waits on the edge of a dream.',
#  'i miss you, really.',
#  'eventually disappear?someday, in a glistening dream,',
#  'a flowing step – a rising face in profile,',
#  'in a place where thunder blooms.',
#  'it’s so bright',
#  'as if begging for love, it sunk into silence,',
#  'ow i see the light in pain',
#  'repeating nothing but tired words, the night is weeping;',
#  'all alone, there was nothing i could do.',
#  'any umbrella that’s been given to me, i no longer have need for –',
#  'a flowing step: but our fingers grazed one another.',
#  'don’t let go, i can’t see,',
#  'blurred crimson and pale',
#  'i just want to be loved.lie, lie, lie, you’re to be with me',
#  'headlights stream out vividly,',
#  '–to turn into the way of life',
#  'i believe the dying light ',
#  'give me sympathy.',
#  'even the cries of migratory birds disappear into the red-stained clouds.',
#  'these words became this song; it won’t reach you',
#  'you were covering your eyes and ears',
#  'let’s overcome this sorrowful night',
#  'please stay by my side, forever.',
#  'unable to say the things we wanna say, the night’s gonna melt away;',
#  'headlights hastily flow away –',
#  'thinking that it was a display of modesty.',
#  'give me sorrow,',
#  'the salt spray whirled into the air, erasing the stardust',
#  'my tears won’t stop.',
#  'should i really find my problem?',
#  'all alone, i couldn’t even use my voice.',
#  'even if i’d been able to touch that scenery i’d realized,',
#  'for a wish that could keep me walking onward.',
#  'all the tears i shed up ’til now- all the feelings i couldn’t put to words-',
#  'as new encounters persist, i learn of my wish.',
#  'let us fill our mouths',
#  'what i wanted to tell you was something pure and ever so slight –',
#  'lie, lie, lie, la la la…the frightened bird',
#  'i bid farewell to the phantoms i’ve met, toward the glowing red sky.',
#  'now you see the light in pain',
#  'the city lights at am02:00 don the shadows of the moon;',
#  'even the city lights i dislike',
#  'i silently wish that i’m right on the edge of a dream.',
#  'you hear? the world is calling',
#  'with the stars swaying to and fro at am03:00, it feels just like a dream.',
#  'i try to dissolve an insolvent night –',
#  'it will get dark soon, so stay by my side.',
#  'rhythm and soul, we areno matter where in the world you are tomorrow,',
#  'move from coast to coast. you don’t need tickets',
#  'will be able to reach you.',
#  'just like always, just like planned, i ran away',
#  'where we follow the outline of a typical summer’s dream.',
#  'i am still hoping',
#  'rhythm and soul beat it',
#  'my ensnared heart showed them all',
#  'this is a miserable, heavenly feeling.',
#  'don’t make this goodbye',
#  'even if the end comes, don’t let it end',
#  'the plankton glow, dancing between darkness and light',
#  'unable to talk about these kind of nights, unable to sleep,',
#  'the more i think of you, why does it make me want to run away?',
#  'we have a definite purpose for our journey',
#  'tomorrow, we’ll see each other as we always do, won’t we?',
#  'let us devour',
#  'i don’t have to throw my life away',
#  'days washed away by the flow of time are in the palm of my hand… like a single flower petal.',
#  'i’m sure you would…',
#  'now do you sleep? how do i sleep?',
#  'these overflowing tears tell no story',
#  'amongst repetitive days, i was searching all along',
#  'gimme just three minutes',
#  'you can find the way of love',
#  'it’s a cycle of sleepless nights as i repeat them, over and over',
#  'now do you sleep? now do you dream?',
#  'to the unseen west of eden,',
#  'as if gently stroking a tiny, fallen bird.',
#  'listening to a voice that won’t fade…',
#  'hey, please stay by my side.',
#  'when i think of you, anxiety is the only thing that remains',
#  'my heart grew chilly and shook, despite having no form',
#  'laughing, pretending not to notice',
#  'tonight’s gonna be another sleepless night!',
#  'and only the unclosing distance between us…',
#  'be moved to tears,',
#  'i make my way down a main street, past the lines of people — heading somewhere far off, to where no one else resides.',
#  'i am still here',
#  'these kinds of feelings on nights we’re not together',
#  'don’t let go.',
#  'do i really want to know about?',
#  'the one causing pain… was me',
#  'i know you’re here to stay with me.',
#  'take my muddy hand, as if to say',
#  'and met you',
#  'is there anything i would say?',
#  '… it’s an unending loop. i remember that way home once again.',
#  'i need myself to sing this song',
#  'a floating step: it’s only the slightest bit,',
#  'lie, lie, lie, la la la…it’s because you smile so vaguely',
#  'it’s okay for me to be unclean.let us form a circle and dance.',
#  'everything goes wrong–',
#  'just what am i to you?',
#  'i’m sure we will…',
#  'the words you said that day',
#  'crying out over and over',
#  'even the tiny flowers that bloom next to the railway,',
#  'all my wish and powers',
#  'i give a kiss to the phantoms i loved, and in the twilit sky,',
#  'i prefer an unbearable amount of spice.',
#  'am03:00.',
#  'wet shirt and wet cheeks… the asphalt;',
#  'as the pain persists, i face new encounters.',
#  'more so than yesterday, there’s surely a definite, brightly shining tomorrow to be found there,',
#  'my heart shook, thinking it was nothing',
#  'even so, i hid them… but i can’t hide them anymore, my true',
#  'what i really wanted to do was cry loudly',
#  'all those people cry in vain',
#  'are dampened; yes, let it rain',
#  'i’ll love you',
#  'why has the act of thinking of you become sad?',
#  'a floating step, in the moonlight.',
#  'how do you feel? what do you feel?',
#  'i grow further away from the road home; right now, i’m all alone, in a place no one else resides.',
#  'you don’t have to throw your life away',
#  'i’ll find you',
#  'they would take me to the gate',
#  'say good bye into the perfect sky',
#  'i bid farewell to the phantoms i’ve met; my longings are amid the sky.',
#  'who can tell why i miss you, really?',
#  'as my weakness spills free, i reach out the palm of my hand… as if holding a single unblooming flower.',
#  'inside this chaotic, oh-so-sweet pot.',
#  'being hurt like this.',
#  'casting a spell, we enter a fairy tale told by angels,',
#  'rhythm and soul beat itlet’s get out',
#  'i don’t need feelings that sit in a picture frame, true',
#  'are swaying their frozen bodies!',
#  'my road home is just a bit more lonely than usual.',
#  'and tell me i’m pathetic.',
#  'forever.',
#  'look down on me,',
#  'invited by the wind at am02:00 is a feeling that just can’t relax;']

# %%
tokenizer = tf.keras.preprocessing.text.Tokenizer()
tokenizer.fit_on_texts(corpus)
total_words = len(tokenizer.word_index) + 1

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import *
from tensorflow.keras.layers import *

# %%
import numpy as np

# %%
input_sequences = []
for line in corpus:
    token_list = tokenizer.texts_to_sequences([line])[0]

    for i in range(1, len(token_list)):
        n_gram_sequence = token_list[:i+1]

    input_sequences.append(n_gram_sequence)

# %%
max_sequence_len = max([len(x) for x in input_sequences])
input_sequences = np.array(tf.keras.utils.pad_sequences(input_sequences,
                       maxlen = max_sequence_len, padding='pre'))

# %%
predictors, label = input_sequences[:,:-1],input_sequences[:,-1]

# %%
maxlen = 1024
vocab_size = len(tokenizer.word_index) + 1
embedding_dim = 128

# %%
model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, mask_zero=True))
model.add(GRU(units=1024, return_sequences=True))
model.add(Dense(vocab_size))

model.compile(optimizer=Adam(), loss=SparseCategoricalCrossentropy(from_logits=True))

history = model.fit(x_train, y_train, epochs=50, verbose=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-fdf347d717db> in <cell line: 6>()
#       4 model.add(Dense(vocab_size))
#       5
# ----> 6 model.compile(optimizer=Adam(), loss=SparseCategoricalCrossentropy(from_logits=True))
#       7
#       8 history = model.fit(x_train, y_train, epochs=50, verbose=1)
#
# NameError: name 'Adam' is not defined

# %%
history = model.fit(predictors, label, epochs= 100, verbose=1)
# Out:
# Epoch 1/100
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-5e7e0491766e> in <cell line: 1>()
# ----> 1 history = model.fit(predictors, label, epochs= 100, verbose=1)
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/training.py", line 1284, in train_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/training.py", line 1268, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/training.py", line 1249, in run_step  **
#         outputs = model.train_step(data)
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/training.py", line 1051, in train_step
#         loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/training.py", line 1109, in compute_loss
#         return self.compiled_loss(
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/compile_utils.py", line 265, in __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "/usr/local/lib/python3.10/dist-packages/keras/losses.py", line 142, in __call__
#         losses = call_fn(y_true, y_pred)
#     File "/usr/local/lib/python3.10/dist-packages/keras/losses.py", line 268, in call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "/usr/local/lib/python3.10/dist-packages/keras/losses.py", line 1984, in categorical_crossentropy
#         return backend.categorical_crossentropy(
#     File "/usr/local/lib/python3.10/dist-packages/keras/backend.py", line 5559, in categorical_crossentropy
#         target.shape.assert_is_compatible_with(output.shape)
#
#     ValueError: Shapes (None, 1) and (None, 679) are incompatible
